# %%
import importlib

import pandas as pd

from common import config

importlib.reload(config)
config.setup_dirs("my_project")
# Out:
# 2025-09-29 15:07:07.960 | INFO     | common.config:<module>:11 - PROJ_ROOT path is: C:\Users\AirtonOliveira\Documents\2-DataProjects\data-workbench
# 2025-09-29 15:07:07.962 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\my_project\raw
# 2025-09-29 15:07:07.962 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\my_project\interim
# 2025-09-29 15:07:07.962 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\my_project\processed
# 2025-09-29 15:07:07.962 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\my_project\external
# 2025-09-29 15:07:07.963 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \models\my_project
# 2025-09-29 15:07:07.963 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \reports\my_project\figures

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})

df.to_csv(config.RAW_DATA_DIR / "my_data.csv", index=False)

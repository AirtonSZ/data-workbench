# %%
import importlib

import pandas as pd

from common import config

importlib.reload(config)
config.setup_dirs("other_project")
# Out:
# 2025-09-29 15:08:57.435 | INFO     | common.config:<module>:11 - PROJ_ROOT path is: C:\Users\AirtonOliveira\Documents\2-DataProjects\data-workbench
# 2025-09-29 15:08:57.458 | INFO     | common.config:<module>:11 - PROJ_ROOT path is: C:\Users\AirtonOliveira\Documents\2-DataProjects\data-workbench
# 2025-09-29 15:08:57.472 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\other_project\raw
# 2025-09-29 15:08:57.474 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\other_project\interim
# 2025-09-29 15:08:57.476 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\other_project\processed
# 2025-09-29 15:08:57.477 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \data\other_project\external
# 2025-09-29 15:08:57.480 | INFO     | common.config:setup_dirs:58 - Ensured directory exists: \models\other_project
# ...

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})

df.to_csv(config.RAW_DATA_DIR / "my_data.csv", index=False)
